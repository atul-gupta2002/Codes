# %% [markdown]
# <a href="https://colab.research.google.com/github/atul-gupta2002/Codes/blob/main/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('heart_2020.csv')

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.size
# Out:
# 5756310

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df.count()
# Out:
# HeartDisease        319795
# BMI                 319795
# Smoking             319795
# AlcoholDrinking     319795
# Stroke              319795
# PhysicalHealth      319795
# MentalHealth        319795
# DiffWalking         319795
# Sex                 319795
# AgeCategory         319795
# Race                319795
# Diabetic            319795
# PhysicalActivity    319795
# GenHealth           319795
# SleepTime           319795
# Asthma              319795
# KidneyDisease       319795
# SkinCancer          319795
# dtype: int64

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['BMI'].plot(kind='hist', bins=20, title='BMI')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
plt.pie(df['HeartDisease'].value_counts(),labels = ['Healthy','HeartDisease'],autopct='%.2f%%')
plt.legend()
plt.show()

# %%
sns.boxplot(df['BMI'])
# Out:
# <Axes: ylabel='BMI'>

# %%
sns.boxplot(df['PhysicalHealth'])
# Out:
# <Axes: ylabel='PhysicalHealth'>

# %%
sns.boxplot(df['MentalHealth'])
# Out:
# <Axes: ylabel='MentalHealth'>

# %%
sns.boxplot(df['SleepTime'])
# Out:
# <Axes: ylabel='SleepTime'>

# %%
plt.figure(figsize=(13,6))
sns.kdeplot(df[df["HeartDisease"]=='No']['SleepTime'], label="No HeartDisease")
sns.kdeplot(df[df["HeartDisease"]=='Yes']['SleepTime'], label="HeartDisease")
plt.legend(title='HeartDisease', fontsize=15,title_fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.select_dtypes(['int64','float64']).corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 18078

# %%
df.drop_duplicates(inplace=True)

# %%
df.BMI.fillna(df.BMI.mean(),inplace=True) #for continuous data

# %% [markdown]
# To find mode

# %%
mode_race = df.Race.value_counts().sort_values(ascending=False)[0:1].reset_index()

# %%
mode_race.iloc[0,0]
# Out:
# 'White'
